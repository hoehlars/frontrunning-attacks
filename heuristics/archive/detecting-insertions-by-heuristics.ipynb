# %% [markdown]
# ### Detecting insertion attacks by heuristics

# %% [markdown]
# According to Frontrunner-Jones insertion attacks can be detected the following way:
#
# A transfer event is triggered on the blockchain, whenever an ERC-20 token is traded.
# An Event combines the following transactional information E = (s,r,a,c,h,i,g):
# - s: sender of tokens
# - r: receiver of tokens
# - a: number of transferred tokens
# - c: contract address of token
# - h: transaction hash
# - i: transaction index
# - g: gas price of transaction
#
# Iterating block by block through all transfer events and checking if there are 3 events EA1, EV, EA2 for which the folloing 6 heuristics hold:

# %% [markdown]
# #### Heuristic 1
#
# Heuristic 1:
# - sender of EA1 must be identical to sender of EV and receiver of EA2
#     - sA1 = sV = rA2
# - receiver of EA1 must be identical to sender of EA2.
#     - rA1 = sA2

# %% [markdown]
# #### Heuristics 2
# - number of tokens bought by EA1 must be similar to the umber of tokens sold by EA2 ( difference of max 1%).

# %% [markdown]
# #### Heuristics 3
# - token contract address of EA1, EV and EA2 must be identical
#     - cA1 = cV2 = cA2

# %% [markdown]
# #### Heuristics 4
# - transaction hashes of EA1, EV and EA2 must be dissimilar
#     - hA1 != hV != hA2

# %% [markdown]
# #### Heuristics 5
# - transaction index of EA1 must be smaller than the transaction index of EV
# - transaction index of EV must be smaller than the transaction index of EA2
#     - iA1 < iV < i A2

# %% [markdown]
# #### Heuristics 6
# - the gas price of EA1 must be larger than the gas price of EV
# - the gas price of EA2 must be less or equal to gas price of EV
#     - gA1 > gV >= gA2

# %% [markdown]
# ### Implementation of Heuristics

# %%
from web3 import Web3

# %%
web3 = Web3(Web3.HTTPProvider("https://intensive-sly-mountain.quiknode.pro/a3f5256d7f2af6541d483cce3f1d49c94c01879e/"))
print("\033[92m"+str(web3.is_connected()))
# Out:
# True

# %%
BLOCK_NUMBER = 5574870
TRANSFER = "0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef" # ERC20 "Transfer"

events = web3.eth.filter({"fromBlock": BLOCK_NUMBER, "toBlock": BLOCK_NUMBER, "topics": [TRANSFER]}).get_all_entries()

coin_contract = events[0]["address"]
sender = events[0]["topics"][2].hex()
print(events[1])
print(coin_contract)
print(sender)
# Out:
# AttributeDict({'address': '0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0', 'topics': [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000010bdcf31074b87627683d83950b3183a10b813f'), HexBytes('0x00000000000000000000000003747f06215b44e498831da019b27f53e483599f')], 'data': HexBytes('0x00000000000000000000000000000000000000000000001e489f0784bcdc8400'), 'blockNumber': 5574870, 'transactionHash': HexBytes('0x1382efde35b60306e4667a8e8c5591175d17f6071a143d33785b8b6075191ba5'), 'transactionIndex': 14, 'blockHash': HexBytes('0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd'), 'logIndex': 2, 'removed': False})
# 0xB62132e35a6c13ee1EE0f84dC5d40bad8d815206
# 0x000000000000000000000000b90812d219071878a75a59571c3279cfc3865ba5

# %%
transactions_by_address = {}

transactions = web3.eth.filter({"fromBlock": BLOCK_NUMBER, "toBlock": BLOCK_NUMBER, "topics": [TRANSFER]}).get_all_entries()

for transaction in transactions:
    
    token_contract_address = transaction["address"]
    
    if token_contract_address in transactions_by_address:
        transactions_by_address[token_contract_address].append(transaction)
    else:
        transactions_by_address[token_contract_address] = [transaction]

# %%
for token_contract_address in transactions_by_address:
    
    nr_of_transactions_with_same_coin = len(transactions_by_address[token_contract_address])
    
    # At least 3 transactions (A1, V, A2)
    if nr_of_transactions_with_same_coin <= 2:
        continue
    
    if token_contract_address != "0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB":
        continue
    
    print(token_contract_address)
    print(nr_of_transactions_with_same_coin)
    
    for transaction in transactions_by_address[token_contract_address]:
        
        address = web3.to_checksum_address(transaction["topics"][2].hex().replace("0x", "")[24:64])
        
        print(transaction["transactionIndex"])
        print(transaction["transactionHash"].hex())
        print(transaction["topics"])
        
        if address in ["0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C",
                       "0x8FB6840a46a8D143DaC1301F560976b953a095C5",
                       "0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C"]:
            pass
            print(transaction)
            

    
    print("\n")
# Out:
# 0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# 8
# 94
# 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000238b7e54dfee4d8e98b8d1a78ab40dd94349bcfd'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b')]
# 94
# 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b'), HexBytes('0x000000000000000000000000c9d9c248a71e5573a4f446b825f915c3e1359239')]
# 96
# 0xff17087b1cde666c6bd5022167a633ddd43b6ee2c929d1c98e493ffb63fe400a
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000238b7e54dfee4d8e98b8d1a78ab40dd94349bcfd'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b')]
# 96
# 0xff17087b1cde666c6bd5022167a633ddd43b6ee2c929d1c98e493ffb63fe400a
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b'), HexBytes('0x000000000000000000000000dfb702d463b378deef627f29b34fbea0eee16b63')]
# 98
# 0xb46caa3c254f3e2050818a1ce3ea6b01f96011b403253c620c9a1720c4a6612a
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000238b7e54dfee4d8e98b8d1a78ab40dd94349bcfd'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b')]
# 98
# 0xb46caa3c254f3e2050818a1ce3ea6b01f96011b403253c620c9a1720c4a6612a
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b'), HexBytes('0x0000000000000000000000008fb6840a46a8d143dac1301f560976b953a095c5')]
# AttributeDict({'address': '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB', 'topics': [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b'), HexBytes('0x0000000000000000000000008fb6840a46a8d143dac1301f560976b953a095c5')], 'data': HexBytes('0x00000000000000000000000000000000000000000001494c2ecef47c9fae5795'), 'blockNumber': 5574870, 'transactionHash': HexBytes('0xb46caa3c254f3e2050818a1ce3ea6b01f96011b403253c620c9a1720c4a6612a'), 'transactionIndex': 98, 'blockHash': HexBytes('0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd'), 'logIndex': 115, 'removed': False})
# 100
# 0x9b4d25a15945cc913732642dc2f9d7b655eac4d8be624f8098c102d653d9c969
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000c9d9c248a71e5573a4f446b825f915c3e1359239'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b')]
# 100
# 0x9b4d25a15945cc913732642dc2f9d7b655eac4d8be624f8098c102d653d9c969
# [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b'), HexBytes('0x000000000000000000000000238b7e54dfee4d8e98b8d1a78ab40dd94349bcfd')]

# %%
BLOCK_NUMBER = 5574870
TRANSFER = "0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef" # ERC20 "Transfer"

for token_contract_address in transactions_by_address:
    
    nr_of_transactions_with_same_coin = len(transactions_by_address[token_contract_address])
    
    # At least 3 transactions (A1, V, A2)
    if nr_of_transactions_with_same_coin <= 2:
        continue
    
    if token_contract_address != "0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB":
        continue
    
    print(token_contract_address)
    print(nr_of_transactions_with_same_coin)
    print("\n")
    
    curr_transaction_index = None
    
    for transaction in transactions_by_address[token_contract_address]:
        
        if curr_transaction_index == transaction["transactionIndex"]:
            last_sender = transaction["topics"][1].hex().replace("0x", "")[24:64]
            last_receiver = transaction["topics"][2].hex().replace("0x", "")[24:64]
        else:
            first_sender = transaction["topics"][1].hex().replace("0x", "")[24:64]
            first_receiver = transaction["topics"][2].hex().replace("0x", "")[24:64]
            last_sender = transaction["topics"][1].hex().replace("0x", "")[24:64]
            last_receiver = transaction["topics"][2].hex().replace("0x", "")[24:64]
            
        curr_transaction_index = transaction["transactionIndex"]
        
        
        
        address = web3.to_checksum_address(transaction["topics"][2].hex().replace("0x", "")[24:64])
        
        print("Position in Block: ", transaction["transactionIndex"])
        #print("hash: ", transaction["transactionHash"].hex())
        print("Token address: ", transaction["address"])
        
        tx = web3.eth.get_transaction(transaction["transactionHash"].hex())
        
        print("Wallet: ", tx["from"]) 
        print("Sender: ", web3.to_checksum_address(transaction["topics"][1].hex().replace("0x", "")[24:64]))
        print("Receiver: ", web3.to_checksum_address(transaction["topics"][2].hex().replace("0x", "")[24:64]))

        #print(transaction["data"].hex())
        print("Amount: ", int(transaction["data"].hex().replace("0x", "")[0:64], 16) / 10 ** 18)
        print("Gas Price: ", tx["gasPrice"] / 10 ** 9)
        
        #print(tx["to"])
        
        if address in ["0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C",
                       "0x8FB6840a46a8D143DaC1301F560976b953a095C5",
                       "0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C"]:
        
            print("")
            
        print("\n")
    
    print("\n")
# Out:
# 0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# 8
#
#
# Position in Block:  94
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# Sender:  0x238B7E54DfEE4d8e98b8D1A78AB40dd94349BcFd
# Receiver:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Amount:  2052115.257102965
# Gas Price:  6.0
#
#
# Position in Block:  94
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# Sender:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Receiver:  0xC9D9c248A71e5573A4f446B825F915C3e1359239
# Amount:  2052115.257102965
# Gas Price:  6.0
#
#
# Position in Block:  96
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0xfF1b9745f68F84F036E5e92c920038d895FB701A
# Sender:  0x238B7E54DfEE4d8e98b8D1A78AB40dd94349BcFd
# Receiver:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Amount:  2190274.9405929167
# Gas Price:  5.98
#
#
# Position in Block:  96
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0xfF1b9745f68F84F036E5e92c920038d895FB701A
# Sender:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Receiver:  0xdfb702D463B378DEEf627F29B34fBea0eEE16b63
# Amount:  2190274.9405929167
# Gas Price:  5.98
#
#
# Position in Block:  98
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0x8FB6840a46a8D143DaC1301F560976b953a095C5
# Sender:  0x238B7E54DfEE4d8e98b8D1A78AB40dd94349BcFd
# Receiver:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Amount:  1555063.8983157023
# Gas Price:  5.34
#
#
# Position in Block:  98
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0x8FB6840a46a8D143DaC1301F560976b953a095C5
# Sender:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Receiver:  0x8FB6840a46a8D143DaC1301F560976b953a095C5
# Amount:  1555063.8983157023
# Gas Price:  5.34
#
#
#
# Position in Block:  100
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# Sender:  0xC9D9c248A71e5573A4f446B825F915C3e1359239
# Receiver:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Amount:  2052115.257102965
# Gas Price:  5.0
#
#
# Position in Block:  100
# Token address:  0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Wallet:  0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# Sender:  0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Receiver:  0x238B7E54DfEE4d8e98b8D1A78AB40dd94349BcFd
# Amount:  2052115.257102965
# Gas Price:  5.0

# %% [markdown]
# ### Approach

# %%
transactions = web3.eth.filter({"fromBlock": BLOCK_NUMBER, "toBlock": BLOCK_NUMBER, "topics": [TRANSFER]}).get_all_entries()

# %%
transaction_indexes = {}

for transaction in transactions:
    
    transaction_index = transaction["transactionIndex"]
    log_index = transaction["logIndex"]
    sender = web3.to_checksum_address(transaction["topics"][1].hex().replace("0x", "")[24:64])
    receiver = web3.to_checksum_address(transaction["topics"][2].hex().replace("0x", "")[24:64])
    address = transaction["address"]
    data =  int(transaction["data"].hex().replace("0x", "")[0:64], 16) 
    tx_hash = transaction["transactionHash"].hex()
    
    if transaction_index not in transaction_indexes:
        transaction_indexes[transaction_index] = {}
        transaction_indexes[transaction_index]["logIndexes"] = []
        transaction_indexes[transaction_index]["sender"] = []
        transaction_indexes[transaction_index]["receiver"] = []
        transaction_indexes[transaction_index]["address"] = []
        transaction_indexes[transaction_index]["data"] = []

    
    transaction_indexes[transaction_index]["logIndexes"].append(log_index)
    transaction_indexes[transaction_index]["sender"].append(sender)
    transaction_indexes[transaction_index]["receiver"].append(receiver)
    transaction_indexes[transaction_index]["address"].append(address)
    transaction_indexes[transaction_index]["data"].append(data)
    transaction_indexes[transaction_index]["transactionHash"] = tx_hash



    
print(transaction_indexes)
# Out:
# {13: {'logIndexes': [0], 'sender': ['0xabf3C296D4aA14052088948f81B67AC99CBa8241'], 'receiver': ['0xb90812d219071878A75a59571c3279CFc3865ba5'], 'address': ['0xB62132e35a6c13ee1EE0f84dC5d40bad8d815206'], 'data': [2962356792140000000000], 'transactionHash': '0xa2b78b6f4e95f568dc9bde036b1959cc53c62a4000e68f746467a308e0f102da'}, 14: {'logIndexes': [2], 'sender': ['0x010bDcf31074B87627683d83950B3183a10b813f'], 'receiver': ['0x03747F06215B44E498831dA019B27f53E483599F'], 'address': ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0'], 'data': [558635231770000000000], 'transactionHash': '0x1382efde35b60306e4667a8e8c5591175d17f6071a143d33785b8b6075191ba5'}, 15: {'logIndexes': [4], 'sender': ['0x2Ff2AD5ff29D51771E8B32229319AA4be9096255'], 'receiver': ['0x03747F06215B44E498831dA019B27f53E483599F'], 'address': ['0xf230b790E05390FC8295F4d3F60332c93BEd42e2'], 'data': [9783370106], 'transactionHash': '0xcfdf7e2afaaf5b67516c50ddba27f104420b85aec20b90f9059418afce06c431'}, 16: {'logIndexes': [6], 'sender': ['0x49d1B466394D233589bBbF4e88bbbb4E010E1A68'], 'receiver': ['0x03747F06215B44E498831dA019B27f53E483599F'], 'address': ['0xf230b790E05390FC8295F4d3F60332c93BEd42e2'], 'data': [74863000000], 'transactionHash': '0x85244a96a6e2a6edcd6d138fbacdc0634b451feb0a0a6c7aeb9ab8e1315fb3d3'}, 17: {'logIndexes': [9], 'sender': ['0xB9BAE58484cABbA0DC6F962d43c32c3E1A6f8730'], 'receiver': ['0x03747F06215B44E498831dA019B27f53E483599F'], 'address': ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0'], 'data': [13000000000000000000000], 'transactionHash': '0xc99265d20aa2c5fcd82068f048458a2ff8344c5ef0d29f1ab5e543f4746bd5ea'}, 18: {'logIndexes': [12], 'sender': ['0xC7dC674c94BE61C881e26828EEd95AE2f724573B'], 'receiver': ['0x03747F06215B44E498831dA019B27f53E483599F'], 'address': ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0'], 'data': [91381873940000000000], 'transactionHash': '0x99362e748249ea80be0aaa4b146be52a60de16a9cbfb2f21d3e582e92a4ec325'}, 19: {'logIndexes': [14], 'sender': ['0xE1956455a2070b7EcA585B7ecd3a51D6915444a9'], 'receiver': ['0x03747F06215B44E498831dA019B27f53E483599F'], 'address': ['0xC5bBaE50781Be1669306b9e001EFF57a2957b09d'], 'data': [2359306417], 'transactionHash': '0x9d9d327d9c02836c93be5285493591a787b59d5b2b82a6bb16b66aae0d7dd86b'}, 20: {'logIndexes': [17], 'sender': ['0x3dB5A42c3E675A127eF417f162F7559Dc252C00b'], 'receiver': ['0x03747F06215B44E498831dA019B27f53E483599F'], 'address': ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0'], 'data': [23185416250000000000], 'transactionHash': '0xde24a35414a1e0cf14a65da7cff7c96c4dc53c6f731624f68156b24efdfa7ac5'}, 21: {'logIndexes': [19], 'sender': ['0xEaD6be34CE315940264519f250d8160f369fa5cd'], 'receiver': ['0x4cD49Ef1eC336e06506e7498642C397dCb814a9b'], 'address': ['0xE41d2489571d322189246DaFA5ebDe1F4699F498'], 'data': [5043000000000000000000], 'transactionHash': '0xa2b7ace4909306c93838f54a2f73f1dbb295f200739717c8e8b8c36f9eb6ea9f'}, 22: {'logIndexes': [20], 'sender': ['0xEaD6be34CE315940264519f250d8160f369fa5cd'], 'receiver': ['0x6a49FA9aD6908CE62A721815FbB3aCc147009779'], 'address': ['0xE41d2489571d322189246DaFA5ebDe1F4699F498'], 'data': [6234687598350000000000], 'transactionHash': '0xf6c6b3cb00ffc16ab2b4f1fe4b58b1a12bc11da77fcf2280871cc3d8324c773d'}, 39: {'logIndexes': [22], 'sender': ['0x358C7746f7eA9A7c3b26a59Ae5189516840BAE5f'], 'receiver': ['0x692DA4782d996DAC7D66B5822f3c504f67dA8493'], 'address': ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0'], 'data': [50922677800000004096], 'transactionHash': '0xdc4b97c2940272b8d70e99919f8f23f0bc83803d5a9f617bbc4583ba89154d69'}, 41: {'logIndexes': [23], 'sender': ['0x343756A75f2Bd17339bac6abdF4Ac05F9e5c86C0'], 'receiver': ['0x47fAd89d0033B56bbE2e3DEf7a5439C2DB51fC4A'], 'address': ['0x73B534fb6F07381a29a60B01eed5ae57D4EE24D7'], 'data': [50000000000000000000], 'transactionHash': '0x7839a6a0336ed24ca61c8dc81f7f0e1b219935134e6b16bc772605a0325726e8'}, 43: {'logIndexes': [24], 'sender': ['0x1e2299c3b844F1E2365F08382c0581671f249688'], 'receiver': ['0x22874863f85Bcc14cFc65eEA5FBe8a791D46 ...

# %%
for tx_index in transaction_indexes:
    
    transaction = transaction_indexes[tx_index]
    
    tx_hash = transaction["transactionHash"]
    tx = web3.eth.get_transaction(tx_hash)
    
    print("Transaction index: ", tx_index)
    print("Token address: ", transaction["address"])
    print("Wallet: ", tx["from"]) 
    print("Gas Price: ", tx["gasPrice"] / 10 ** 9)
   
    first_log_idx = transaction["logIndexes"][0]
    last_log_idx = transaction["logIndexes"][-1]

    first_sender = transaction["sender"][0]
    first_receiver = transaction["receiver"][0]
    
    last_sender = transaction["sender"][-1]
    last_receiver = transaction["receiver"][-1]
    
    print(f"{first_log_idx}, {last_log_idx}")
    print(f"{first_sender}, {first_receiver}")
    print(f"{last_sender}, {last_receiver}")
    print("\n")
# Out:
# Transaction index:  13
# Token address:  ['0xB62132e35a6c13ee1EE0f84dC5d40bad8d815206']
# Wallet:  0xabf3C296D4aA14052088948f81B67AC99CBa8241
# Gas Price:  55.0
# 0, 0
# 0xabf3C296D4aA14052088948f81B67AC99CBa8241, 0xb90812d219071878A75a59571c3279CFc3865ba5
# 0xabf3C296D4aA14052088948f81B67AC99CBa8241, 0xb90812d219071878A75a59571c3279CFc3865ba5
#
#
# Transaction index:  14
# Token address:  ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0']
# Wallet:  0x03747F06215B44E498831dA019B27f53E483599F
# Gas Price:  53.2
# 2, 2
# 0x010bDcf31074B87627683d83950B3183a10b813f, 0x03747F06215B44E498831dA019B27f53E483599F
# 0x010bDcf31074B87627683d83950B3183a10b813f, 0x03747F06215B44E498831dA019B27f53E483599F
#
#
# Transaction index:  15
# Token address:  ['0xf230b790E05390FC8295F4d3F60332c93BEd42e2']
# Wallet:  0x03747F06215B44E498831dA019B27f53E483599F
# Gas Price:  53.2
# 4, 4
# 0x2Ff2AD5ff29D51771E8B32229319AA4be9096255, 0x03747F06215B44E498831dA019B27f53E483599F
# 0x2Ff2AD5ff29D51771E8B32229319AA4be9096255, 0x03747F06215B44E498831dA019B27f53E483599F
#
#
# Transaction index:  16
# Token address:  ['0xf230b790E05390FC8295F4d3F60332c93BEd42e2']
# Wallet:  0x03747F06215B44E498831dA019B27f53E483599F
# Gas Price:  53.2
# 6, 6
# 0x49d1B466394D233589bBbF4e88bbbb4E010E1A68, 0x03747F06215B44E498831dA019B27f53E483599F
# 0x49d1B466394D233589bBbF4e88bbbb4E010E1A68, 0x03747F06215B44E498831dA019B27f53E483599F
#
#
# Transaction index:  17
# Token address:  ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0']
# Wallet:  0x03747F06215B44E498831dA019B27f53E483599F
# Gas Price:  53.2
# 9, 9
# 0xB9BAE58484cABbA0DC6F962d43c32c3E1A6f8730, 0x03747F06215B44E498831dA019B27f53E483599F
# 0xB9BAE58484cABbA0DC6F962d43c32c3E1A6f8730, 0x03747F06215B44E498831dA019B27f53E483599F
#
#
# Transaction index:  18
# Token address:  ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0']
# Wallet:  0x03747F06215B44E498831dA019B27f53E483599F
# Gas Price:  53.2
# 12, 12
# 0xC7dC674c94BE61C881e26828EEd95AE2f724573B, 0x03747F06215B44E498831dA019B27f53E483599F
# 0xC7dC674c94BE61C881e26828EEd95AE2f724573B, 0x03747F06215B44E498831dA019B27f53E483599F
#
#
# Transaction index:  19
# Token address:  ['0xC5bBaE50781Be1669306b9e001EFF57a2957b09d']
# Wallet:  0x03747F06215B44E498831dA019B27f53E483599F
# Gas Price:  53.2
# 14, 14
# 0xE1956455a2070b7EcA585B7ecd3a51D6915444a9, 0x03747F06215B44E498831dA019B27f53E483599F
# 0xE1956455a2070b7EcA585B7ecd3a51D6915444a9, 0x03747F06215B44E498831dA019B27f53E483599F
#
#
# Transaction index:  20
# Token address:  ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0']
# Wallet:  0x03747F06215B44E498831dA019B27f53E483599F
# Gas Price:  53.2
# 17, 17
# 0x3dB5A42c3E675A127eF417f162F7559Dc252C00b, 0x03747F06215B44E498831dA019B27f53E483599F
# 0x3dB5A42c3E675A127eF417f162F7559Dc252C00b, 0x03747F06215B44E498831dA019B27f53E483599F
#
#
# Transaction index:  21
# Token address:  ['0xE41d2489571d322189246DaFA5ebDe1F4699F498']
# Wallet:  0xEaD6be34CE315940264519f250d8160f369fa5cd
# Gas Price:  51.9
# 19, 19
# 0xEaD6be34CE315940264519f250d8160f369fa5cd, 0x4cD49Ef1eC336e06506e7498642C397dCb814a9b
# 0xEaD6be34CE315940264519f250d8160f369fa5cd, 0x4cD49Ef1eC336e06506e7498642C397dCb814a9b
#
#
# Transaction index:  22
# Token address:  ['0xE41d2489571d322189246DaFA5ebDe1F4699F498']
# Wallet:  0xEaD6be34CE315940264519f250d8160f369fa5cd
# Gas Price:  51.9
# 20, 20
# 0xEaD6be34CE315940264519f250d8160f369fa5cd, 0x6a49FA9aD6908CE62A721815FbB3aCc147009779
# 0xEaD6be34CE315940264519f250d8160f369fa5cd, 0x6a49FA9aD6908CE62A721815FbB3aCc147009779
#
#
# Transaction index:  39
# Token address:  ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0']
# Wallet:  0x358C7746f7eA9A7c3b26a59Ae5189516840BAE5f
# Gas Price:  22.2
# 22, 22
# 0x358C7746f7eA9A7c3b26a59Ae5189516840BAE5f, 0x692DA4782d996DAC7D66B5822f3c504f67dA8493
# 0x358C7746f7eA9A7c3b26a59Ae5189516840BAE5f, 0x692DA4782d996DAC7D66B5822f3c504f67dA8493
#
#
# Transaction index:  41
# Token address:  ['0x73B534fb6F07381a29a60B01eed5ae57D4EE24D7']
# Wallet:  0x343756A75f2Bd17339bac6abdF4Ac05F9e5c86C0
# Gas Price:  21.0
# 23, 23
# 0x343756A75f2Bd17339bac6abdF4Ac05F9e5c86C0, 0x47fAd89d0033B56bbE2e3DEf7a5439C2DB51fC4A
# 0x343756A75f2Bd17339bac6abdF4Ac05F9e5c86C0, 0x47fAd89d0033B56bbE2e3DEf7a5439C2DB51fC4A
#
#
# Transaction index:  43
# Token address:  ['0x905E337c6c8645263D3521205Aa37bf4d034e745']
# Wallet:  0x1e2299c3b844F1E2365F08382c0581671f249688
# Gas Price:  20.0
# 24, 24
# 0x1e2299c3b844F1E2365F08382c0581671f249688, 0x22874863f85Bcc14cFc65eEA5FBe8a791D46ec3D
# 0x1e2299c3b844F1E2365F08382c0581671f249688, 0x22874863f85Bcc14cFc65eEA5FBe8a791D46ec3D
#
#
# Transaction index:  45
# Token address:  ['0xc42209aCcC14029c1012fB5680D95fBd6036E2a0']
# Wallet:  0xfBFade39eFdfCE3CD65FDc9487453126a4a95e3f
# Gas Price:  20.0
# 25, 25
# 0xfBFade39eFdfCE3CD65FDc9487453126a4a95e3f, 0xe4fE9d9B6D1a69F0Fc5Ef21b1e6b525782054AA5
# 0xfBFade39eFdfCE3CD65FDc9487453126a4a95e3f, 0xe4fE9d9B6D1a69F0Fc5Ef21b1e6b525782054AA5
#
#
# Transaction index:  46
# Token address:  ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0']
# Wallet:  0xA5224C410A14255c94B29381Ed96Be873A063FDb
# Gas Price:  20.0
# 27, 27
# 0xA5224C410A14255c94B29381Ed96Be873A063FDb, 0x639d9BA0f11Ff73A25c0a26849D4d5A7175169b6
# 0xA5224C410A14255c94B29381Ed96Be873A063FDb, 0x639d9BA0f11Ff73A25c0a26849D4d5A7175169b6
#
#
# Transaction index:  48
# Token address:  ['0xb8Eb7073716BcC6bEEd4fCE7CdA2E64DA8Ef8Bd3']
# Wallet:  0x3d3f7F103bb05fabA3f4A79F44417688981C0E90
# Gas Price:  17.40625
# 28, 28
# 0x3d3f7F103bb05fabA3f4A79F44417688981C0E90, 0xB40Ad2da9657cbD4ae8372A7b125c62c26C8d3a5
# 0x3d3f7F103bb05fabA3f4A79F44417688981C0E90, 0xB40Ad2da9657cbD4ae8372A7b125c62c26C8d3a5
#
#
# Transaction index:  52
# Token address:  ['0xd4fa1460F537bb9085d22C7bcCB5DD450Ef28e3a']
# Wallet:  0x0C765eEC75896d2eb01d56c77EA93dc8B1B2df4d
# Gas Price:  15.0
# 29, 29
# 0x0C765eEC75896d2eb01d56c77EA93dc8B1B2df4d, 0xeBB86fd5d89F5270245418703cB4F2Ed1e9248AA
# 0x0C765eEC75896d2eb01d56c77EA93dc8B1B2df4d, 0xeBB86fd5d89F5270245418703cB4F2Ed1e9248AA
#
#
# Transaction index:  54
# Token address:  ['0xE41d2489571d322189246DaFA5ebDe1F4699F498']
# Wallet:  0x4cD49Ef1eC336e06506e7498642C397dCb814a9b
# Gas Price:  12.2
# 30, 30
# 0x4cD49Ef1eC336e06506e7498642C397dCb814a9b, 0x591D86019a0dB96681F070E6ce46E3f5577e4288
# 0x4cD49Ef1eC336e06506e7498642C397dCb814a9b, 0x591D86019a0dB96681F070E6ce46E3f5577e4288
#
#
# Transaction index:  83
# Token address:  ['0x05f4a42e251f2d52b8ed15E9FEdAacFcEF1FAD27']
# Wallet:  0x63211543AFD714b68d9Bf5Ee963e97796C0387b8
# Gas Price:  8.0
# 46, 46
# 0x63211543AFD714b68d9Bf5Ee963e97796C0387b8, 0x6cA7e4A83AEe7f73527887bd3E2cC8Ce57ad996D
# 0x63211543AFD714b68d9Bf5Ee963e97796C0387b8, 0x6cA7e4A83AEe7f73527887bd3E2cC8Ce57ad996D
#
#
# Transaction index:  91
# Token address:  ['0x41dBECc1cdC5517C6f76f6a6E836aDbEe2754DE3']
# Wallet:  0x5cA394073fe75dC860C9fdbC0EFef89b99B606C6
# Gas Price:  6.2
# 47, 47
# 0x5cA394073fe75dC860C9fdbC0EFef89b99B606C6, 0x1062a747393198f70F71ec65A582423Dba7E5Ab3
# 0x5cA394073fe75dC860C9fdbC0EFef89b99B606C6, 0x1062a747393198f70F71ec65A582423Dba7E5Ab3
#
#
# Transaction index:  93
# Token address:  ['0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0xa7774F9386E1653645E1A08fb7Aae525B4DeDb24', '0xa7774F9386E1653645E1A08fb7Aae525B4DeDb24', '0x419c4dB4B9e25d6Db2AD9691ccb832C8D9fDA05E', '0x419c4dB4B9e25d6Db2AD9691ccb832C8D9fDA05E']
# Wallet:  0x50D3b2A217736B9cF92EE286e2539bC2CEb2DA33
# Gas Price:  6.0
# 48, 61
# 0x50D3b2A217736B9cF92EE286e2539bC2CEb2DA33, 0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C
# 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B, 0x50D3b2A217736B9cF92EE286e2539bC2CEb2DA33
#
#
# Transaction index:  94
# Token address:  ['0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB', '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB']
# Wallet:  0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# Gas Price:  6.0
# 63, 79
# 0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315, 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B, 0xC9D9c248A71e5573A4f446B825F915C3e1359239
#
#
# Transaction index:  96
# Token address:  ['0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB', '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB']
# Wallet:  0xfF1b9745f68F84F036E5e92c920038d895FB701A
# Gas Price:  5.98
# 81, 96
# 0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315, 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B, 0xdfb702D463B378DEEf627F29B34fBea0eEE16b63
#
#
# Transaction index:  97
# Token address:  ['0xD6df5935cD03a768b7B9E92637A01b25e24cb709']
# Wallet:  0xbA743bF19180fae355c13DFB41097e4bc5bfb8e4
# Gas Price:  5.7283584
# 98, 98
# 0x0000000000000000000000000000000000000000, 0xbA743bF19180fae355c13DFB41097e4bc5bfb8e4
# 0x0000000000000000000000000000000000000000, 0xbA743bF19180fae355c13DFB41097e4bc5bfb8e4
#
#
# Transaction index:  98
# Token address:  ['0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB', '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB']
# Wallet:  0x8FB6840a46a8D143DaC1301F560976b953a095C5
# Gas Price:  5.34
# 100, 115
# 0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315, 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B, 0x8FB6840a46a8D143DaC1301F560976b953a095C5
#
#
# Transaction index:  99
# Token address:  ['0xB62132e35a6c13ee1EE0f84dC5d40bad8d815206']
# Wallet:  0xfA25C9B1BD59DCA9397f04abdA4f566c6C931040
# Gas Price:  5.0
# 116, 116
# 0xfA25C9B1BD59DCA9397f04abdA4f566c6C931040, 0x3722c9B7e34Eab0103632D77f8b937c3c272bDF5
# 0xfA25C9B1BD59DCA9397f04abdA4f566c6C931040, 0x3722c9B7e34Eab0103632D77f8b937c3c272bDF5
#
#
# Transaction index:  100
# Token address:  ['0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB', '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0xA9DE5935aE3eae8a7F943C9329940EDA160267f4', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C', '0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315', '0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315']
# Wallet:  0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# Gas Price:  5.0
# 117, 133
# 0xC9D9c248A71e5573A4f446B825F915C3e1359239, 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# 0xC9D9c248A71e5573A4f446B825F915C3e1359239, 0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315
#
#
# Transaction index:  107
# Token address:  ['0xc6689EB9a6D724B8D7B1d923fFd65B7005dA1b62']
# Wallet:  0xD3Fc9AF68Dd924E0dF8752DeE294c039143661Dd
# Gas Price:  3.11
# 141, 141
# 0xD3Fc9AF68Dd924E0dF8752DeE294c039143661Dd, 0x93f36930F94FBB5aFc5fB506D3f7ABB9179a4e4e
# 0xD3Fc9AF68Dd924E0dF8752DeE294c039143661Dd, 0x93f36930F94FBB5aFc5fB506D3f7ABB9179a4e4e
#
#
# Transaction index:  108
# Token address:  ['0xc6689EB9a6D724B8D7B1d923fFd65B7005dA1b62']
# Wallet:  0xf97CeEc3A2DB525f0a9B87A66D55a232b86aE3a4
# Gas Price:  3.11
# 142, 142
# 0xf97CeEc3A2DB525f0a9B87A66D55a232b86aE3a4, 0x93f36930F94FBB5aFc5fB506D3f7ABB9179a4e4e
# 0xf97CeEc3A2DB525f0a9B87A66D55a232b86aE3a4, 0x93f36930F94FBB5aFc5fB506D3f7ABB9179a4e4e
#
#
# Transaction index:  109
# Token address:  ['0x419D0d8BdD9aF5e606Ae2232ed285Aff190E711b']
# Wallet:  0xdb26819183703B78C4F6880a1C1f34fe2E156E0F
# Gas Price:  3.0
# 143, 143
# 0xdb26819183703B78C4F6880a1C1f34fe2E156E0F, 0xA6032f70d7Daf1FEe752D83e01FF672C28832CEf
# 0xdb26819183703B78C4F6880a1C1f34fe2E156E0F, 0xA6032f70d7Daf1FEe752D83e01FF672C28832CEf
#
#
# Transaction index:  117
# Token address:  ['0xdd974D5C2e2928deA5F71b9825b8b646686BD200', '0xdd974D5C2e2928deA5F71b9825b8b646686BD200']
# Wallet:  0x6D99d6Da0Dd32A68394DD90ADADf54DDEF44d571
# Gas Price:  3.0
# 144, 146
# 0x2AAb2b157a03915c8a73ADaE735d0Cf51c872F31, 0x964F35fAe36d75B1e72770e244F6595B68508CF5
# 0x964F35fAe36d75B1e72770e244F6595B68508CF5, 0x6D99d6Da0Dd32A68394DD90ADADf54DDEF44d571
#
#
# Transaction index:  118
# Token address:  ['0x558EC3152e2eb2174905cd19AeA4e34A23DE9aD6']
# Wallet:  0xD867BBAe0154D55B9fBFAD45d007eE79cDa5804e
# Gas Price:  2.42
# 150, 150
# 0xD867BBAe0154D55B9fBFAD45d007eE79cDa5804e, 0x77749c7b289C8256A698F276b9E9a3fFD71EbB9F
# 0xD867BBAe0154D55B9fBFAD45d007eE79cDa5804e, 0x77749c7b289C8256A698F276b9E9a3fFD71EbB9F
#
#
# Transaction index:  122
# Token address:  ['0xFBE0e9846Bd736B84A0A973322AD2a1fC8d7E5CA']
# Wallet:  0xf2675e75EDc964E63E7B31C74200aAa80fAF19ff
# Gas Price:  2.2
# 152, 152
# 0xf2675e75EDc964E63E7B31C74200aAa80fAF19ff, 0xF8C1e9578f9AA3477432510aac2e38955E6E9826
# 0xf2675e75EDc964E63E7B31C74200aAa80fAF19ff, 0xF8C1e9578f9AA3477432510aac2e38955E6E9826
#
#
# Transaction index:  123
# Token address:  ['0x57B116DA40F21f91AeC57329EcB763D29c1B2355']
# Wallet:  0xE8F55d359164fC43be0a49379F728a4Fa01E522C
# Gas Price:  2.1
# 153, 153
# 0xE8F55d359164fC43be0a49379F728a4Fa01E522C, 0x41F29054E7c0BC59a8AF10f3a6e7C0E53B334e05
# 0xE8F55d359164fC43be0a49379F728a4Fa01E522C, 0x41F29054E7c0BC59a8AF10f3a6e7C0E53B334e05
#
#
# Transaction index:  126
# Token address:  ['0x86Fa049857E0209aa7D9e616F7eb3b3B78ECfdb0']
# Wallet:  0xb795eA294044BBcC4B61c661C3CBe9aCB374EacA
# Gas Price:  2.0
# 155, 155
# 0xb795eA294044BBcC4B61c661C3CBe9aCB374EacA, 0x83761c6785427F5A27a07c92a9dcFa99947bC4AD
# 0xb795eA294044BBcC4B61c661C3CBe9aCB374EacA, 0x83761c6785427F5A27a07c92a9dcFa99947bC4AD
#
#
# Transaction index:  131
# Token address:  ['0x69b148395Ce0015C13e36BFfBAd63f49EF874E03']
# Wallet:  0xE7260DE0154bC6e695007b2C46A8e2BE30c56E45
# Gas Price:  1.0
# 157, 157
# 0xE7260DE0154bC6e695007b2C46A8e2BE30c56E45, 0x07746F3c3dAe643576D0d2728ba6Cf6dB04d902C
# 0xE7260DE0154bC6e695007b2C46A8e2BE30c56E45, 0x07746F3c3dAe643576D0d2728ba6Cf6dB04d902C
#
#
# Transaction index:  143
# Token address:  ['0x3833ddA0AEB6947b98cE454d89366cBA8Cc55528']
# Wallet:  0xff4e418434dEE98C980BA1b26EcfF16dF5cFc0FD
# Gas Price:  1.0
# 163, 163
# 0xff4e418434dEE98C980BA1b26EcfF16dF5cFc0FD, 0xeB4a235bE50f3eA6a72FD7326daa64e4A51FE296
# 0xff4e418434dEE98C980BA1b26EcfF16dF5cFc0FD, 0xeB4a235bE50f3eA6a72FD7326daa64e4A51FE296
#
#
# Transaction index:  147
# Token address:  ['0xf230b790E05390FC8295F4d3F60332c93BEd42e2']
# Wallet:  0x76B2546B4A7f3b96018F88b86232f5044c33807b
# Gas Price:  1.0
# 164, 164
# 0x76B2546B4A7f3b96018F88b86232f5044c33807b, 0xFFE7Aa08dA702aCc45A619A3E1800ee8Fed2ba90
# 0x76B2546B4A7f3b96018F88b86232f5044c33807b, 0xFFE7Aa08dA702aCc45A619A3E1800ee8Fed2ba90
#
#
# Transaction index:  150
# Token address:  ['0xa701122c1b67220a8B6883D03C8Ad67896B12466']
# Wallet:  0x44d06B9080283e1F76aE6468ee25c8dDC4f609d6
# Gas Price:  1.0
# 165, 165
# 0x44d06B9080283e1F76aE6468ee25c8dDC4f609d6, 0x68BB7b75241D8D4cca52b1a40A688861C010a8E4
# 0x44d06B9080283e1F76aE6468ee25c8dDC4f609d6, 0x68BB7b75241D8D4cca52b1a40A688861C010a8E4

# %%
def print_attribute_dict(attribute_dict):
    
    for key, value in attribute_dict.items():
        
        if key == "topics":
            for i, el in enumerate(value):
                value =  web3.to_checksum_address(el.hex().replace("0x", "")[24:64])
                print(f"Topic {i}: {value}")
            continue
        
        try:
            value = value.hex()
        except:
            pass
        print(f"{key}: {value}")

# %%
for t in transactions:
    
    if t["transactionIndex"] not in [94]:
        continue
    print_attribute_dict(t)
    print("\n")
# Out:
# address: 0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315
# Topic 2: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# data: 0x00000000000000000000000000000000000000000000000055c6d2da9d849600
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 63
# removed: False
#
#
# address: 0xc0829421C1d260BD3cB3E0F06cfE2D52db2cE315
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Topic 2: 0xc6725aE749677f21E4d8f85F41cFB6DE49b9Db29
# data: 0x00000000000000000000000000000000000000000000000055c6d2da9d849600
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 65
# removed: False
#
#
# address: 0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C
# Topic 2: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# data: 0x0000000000000000000000000000000000000000000000322e9d8358daf8cb61
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 67
# removed: False
#
#
# address: 0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Topic 2: 0x238B7E54DfEE4d8e98b8D1A78AB40dd94349BcFd
# data: 0x0000000000000000000000000000000000000000000000322e9d8358daf8cb61
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 70
# removed: False
#
#
# address: 0xA9DE5935aE3eae8a7F943C9329940EDA160267f4
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0xA9DE5935aE3eae8a7F943C9329940EDA160267f4
# Topic 2: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# data: 0x00000000000000000000000000000000000000000000001d4bf47e393d013cdf
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 72
# removed: False
#
#
# address: 0xA9DE5935aE3eae8a7F943C9329940EDA160267f4
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Topic 2: 0xA9DE5935aE3eae8a7F943C9329940EDA160267f4
# data: 0x00000000000000000000000000000000000000000000001d4bf47e393d013cdf
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 74
# removed: False
#
#
# address: 0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0x238B7E54DfEE4d8e98b8D1A78AB40dd94349BcFd
# Topic 2: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# data: 0x00000000000000000000000000000000000000000001b28d64186289756ed94a
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 76
# removed: False
#
#
# address: 0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB
# Topic 0: 0xFC378dAA952ba7f163c4a11628f55a4df523b3EF
# Topic 1: 0xcF1CC6eD5B653DeF7417E3fA93992c3FFe49139B
# Topic 2: 0xC9D9c248A71e5573A4f446B825F915C3e1359239
# data: 0x00000000000000000000000000000000000000000001b28d64186289756ed94a
# blockNumber: 5574870
# transactionHash: 0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090
# transactionIndex: 94
# blockHash: 0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd
# logIndex: 79
# removed: False

# %%
transactions = web3.eth.filter({"fromBlock": BLOCK_NUMBER, "toBlock": BLOCK_NUMBER, "topics": [TRANSFER]}).get_all_entries()

# %%
for transaction in transactions:
    
    address = web3.to_checksum_address(transaction["topics"][2].hex().replace("0x", "")[24:64])
    
    if (address in 
            ["0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C",
             "0x8FB6840a46a8D143DaC1301F560976b953a095C5",
             "0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C"]):
        
        print(transaction)
# Out:
# AttributeDict({'address': '0x9a0242b7a33DAcbe40eDb927834F96eB39f8fBCB', 'topics': [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'), HexBytes('0x000000000000000000000000cf1cc6ed5b653def7417e3fa93992c3ffe49139b'), HexBytes('0x0000000000000000000000008fb6840a46a8d143dac1301f560976b953a095c5')], 'data': HexBytes('0x00000000000000000000000000000000000000000001494c2ecef47c9fae5795'), 'blockNumber': 5574870, 'transactionHash': HexBytes('0xb46caa3c254f3e2050818a1ce3ea6b01f96011b403253c620c9a1720c4a6612a'), 'transactionIndex': 98, 'blockHash': HexBytes('0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd'), 'logIndex': 115, 'removed': False})

# %%
block = web3.eth.get_block(BLOCK_NUMBER, full_transactions=True)

for transaction in block.transactions:
        
    address = transaction["from"]
    
    if (address in 
            ["0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C",
             "0x8FB6840a46a8D143DaC1301F560976b953a095C5",
             "0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C"]):
        
        print(transaction)
        print(transaction["from"])
        print(transaction["to"])
        print(transaction["transactionIndex"])
# Out:
# AttributeDict({'blockHash': HexBytes('0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd'), 'blockNumber': 5574870, 'from': '0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C', 'gas': 840000, 'gasPrice': 6000000000, 'hash': HexBytes('0xedee87cdea91b70805184a1dbd32f689b02ff6f40579a601c2a4dd249d9b8090'), 'input': HexBytes('...'), 'nonce': 1819, 'to': '0xC9D9c248A71e5573A4f446B825F915C3e1359239', 'transactionIndex': 94, 'value': 0, 'type': 0, 'chainId': 1, 'v': 38, 'r': HexBytes('0x7bea2e924091820714d4f7f77389a2f5cf0a61c68be8866cd2bd13b3820d6a25'), 's': HexBytes('0x08ea5dbcd36fbc38fff0673c01b9bd70dc8ca149958c0754ea1b0e4d4beda61b')})
# 0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# 0xC9D9c248A71e5573A4f446B825F915C3e1359239
# 94
# AttributeDict({'blockHash': HexBytes('0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd'), 'blockNumber': 5574870, 'from': '0x8FB6840a46a8D143DaC1301F560976b953a095C5', 'gas': 692860, 'gasPrice': 5340000000, 'hash': HexBytes('0xb46caa3c254f3e2050818a1ce3ea6b01f96011b403253c620c9a1720c4a6612a'), 'input': HexBytes('...'), 'nonce': 169, 'to': '0xc6725aE749677f21E4d8f85F41cFB6DE49b9Db29', 'transactionIndex': 98, 'value': 4830673103642542756, 'type': 0, 'chainId': 1, 'v': 38, 'r': HexBytes('0x42296366fa3fc60847e367d2994712da537b231553df5477f83fbeee2608430b'), 's': HexBytes('0x5ee7e64a0e7bc3a049bc917f9668cf59ea61b32011e45da83e812177a8e6ead3')})
# 0x8FB6840a46a8D143DaC1301F560976b953a095C5
# 0xc6725aE749677f21E4d8f85F41cFB6DE49b9Db29
# 98
# AttributeDict({'blockHash': HexBytes('0x8afa98014df9eb5d6305d1e8caad29dd0c162d6c809009a75e1e148a118e63dd'), 'blockNumber': 5574870, 'from': '0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C', 'gas': 840000, 'gasPrice': 5000000000, 'hash': HexBytes('0x9b4d25a15945cc913732642dc2f9d7b655eac4d8be624f8098c102d653d9c969'), 'input': HexBytes('...'), 'nonce': 1820, 'to': '0xC9D9c248A71e5573A4f446B825F915C3e1359239', 'transactionIndex': 100, 'value': 0, 'type': 0, 'chainId': 1, 'v': 38, 'r': HexBytes('0x735e421f301788aeaaf7e9b73d5cc6bf0a88b4ff50a5635df1cb581fed394be5'), 's': HexBytes('0x190251619a100492384490a6fc462ad118fd3ba5b443cac2003c9222d34a8999')})
# 0x4fCc2FF6c75923D33B4F5aF4C524461014B2EE1C
# 0xC9D9c248A71e5573A4f446B825F915C3e1359239
# 100
